# %% [markdown]
# # 1.0. Project Overview
#  Project Overview
#
# For this project, you will use exploratory data analysis to generate insights for a business stakeholder.
#
# ### 1.0.1. Business Problem
#
# Microsoft sees all the big companies creating original video content and they want to get in on the fun. They have decided to create a new movie studio, but they don’t know anything about creating movies. You are charged with exploring what types of films are currently doing the best at the box office. You must then translate those findings into actionable insights that the head of Microsoft's new movie studio can use to help decide what type of films to create.
#
# ### 1.0.2. The Data
#
# In the folder `zippedData` are movie datasets from:
#
# * [Box Office Mojo](bom.movie_gross.csv)
# * [IMDB](https://www.imdb.com/)
# * [Rotten Tomatoes](https://www.rottentomatoes.com/)
# * [TheMovieDB](tmdb.movies.csv)
# * [The Numbers](tn.movie_budgets.csv)
#
#
# ### 1.0.3. Key Points
#
# * **Your analysis should yield three concrete business recommendations.**
# The ultimate purpose of exploratory analysis is not just to learn about the data, but to help an organization perform better. Explicitly relate your findings to business needs by recommending actions that you think the business (Microsoft) should take.
#
# * **Communicating about your work well is extremely important.**
# Create a storyline your audience (the head of Microsoft's new movie studio) can follow by walking them through the steps of your process, highlighting the most important points and skipping over the rest.
#
# * **Use plenty of visualizations.**
# Visualizations are invaluable for exploring your data and making your findings accessible to a non-technical audience. Spotlight visuals in your presentation, but only ones that relate directly to your recommendations. Simple visuals are usually best (e.g. bar charts and line graphs), and don't forget to format them well (e.g. labels, titles)

# %% [markdown]
# # 1.2.0 Analysis and Visualization
#
#    #### (I)   EDA (Exploratory Data Analysis )
# In order to reach the best conclusion I hereby present the steps taken to load, clean , manipulate and visualize the datasets' info accordingly i.e, in order to get the best result and draw an informed conclusion and eventually recommend the best way to implement the output and probably enter the entertainment industry with the best data at hand.
#
#  The data for the analysis will be combined into one dataFrame in order to give a wide source of data and get a wide variety of data to work on but in one container i.e, the DataFrame.
#
#  The main libraries used in this analysis will be the Pandas library, Matplotlib.pyplot- for visualization, Seaborn for suplementing visualizations with matplotlib.pylot library and NumPy for arithmetic operations e.g,operations involving Statistical methods.
#
#    ####   (II).  Output and Visualizations
# The output mainly includes movies, their ratings, managers, salaries, best actors, movie-votes,...etc.
#
# This is just to allow the client to understand the data easily and make the best decision out of the final recommendation.
#
#    #### (III). Recommendation
#  I believe the movie industry is lucrative and would add more value to your company given the great performance and feedback from customers so far.
#
#  Best products stay so when a new best product is introduced the relationship between products is dynamically mutual and a good perfoming product influences performance of the other products on the company's portfolio.
#
#  The Customer Relationship Management(CRM) in place is good and the company would thrive well in the industry mind you, it is a competitive and fast-growing industry; the best data at hand means current data which is extensively exploited in this nalysis.

# %% [markdown]
# ## 2.0. Importing Relevant libraries for data analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2.1.  Loading the data

# %%
# Loading the "bom.movies" data using pandas csv file reader

df = pd.DataFrame()

data = pd.read_csv("bom.movie_gross.csv")

# Assign the 'data' DataFrame to the 'bom_movies' Dataset
df.bom_movies = data

# Display the first few rows of the 'bom_movies' dataset

df.bom_movies.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# Loading the "tn.movie_budgets" data using the pandas csv file reader

df = pd.DataFrame()

data = pd.read_csv("tn.movie_budgets.csv")

# Assign the 'data' DataFrame to the 'tn.movie_budgets' Dataset
tn_movie_budgets = data

# Display the first few rows of the 'tn_movie_budgets' DataFrame
tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# Rename the 'movie' column to 'title'
tn_movie_budgets.rename(columns={'movie': 'title'}, inplace=True)
tn_movie_budgets.head()
# Out:
#    id  release_date                                        title  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# Assign the 'data' DataFrame to the 'tn.movie_budgets' Dataset
data = pd.read_csv("tn.movie_budgets.csv")

# Assign the 'data' DataFrame to the 'tn.movie_budgets' Dataset
tn_movie_budgets = data

# Mapping abbreviated month names to numerical values
month_mapping = {
    'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
    'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12
}
# Convert 'release_date' to datetime
tn_movie_budgets['release_date'] = pd.to_datetime(tn_movie_budgets['release_date'])

tn_movie_budgets.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# Loading the 'tmdb.movies' data using the pandas csv file reader
df = pd.DataFrame()

data = pd.read_csv("tmdb.movies.csv")

# Assign the 'data' DataFrame to the 'tmdb.movies' Dataset
tmdb_movies = data

# Display the first few rows of the 'tmdb_movies' DataFrame

tmdb_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %% [markdown]
# # 3.0. Data Preparation

# %% [markdown]
# The datasets provided above have a few irrelevant features that require appropriate handling for conclusion of a smooth analysis and inculcate accuracy and efficiency in reaching the final reommendation.
#
# The steps involved in this process include: dropping/replacing missing values, handling duplicates in the data, formatting data inconsistencies and formatting Datatypes.
#
# Finally the clean datasets will be combined into one DataFrame.

# %% [markdown]
# # 3.1. Combining the datasets into one DataFrame

# %%
# Drop the 'Unnamed' column in the tmdb_movies dataset
tmdb_movies.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Assign the 'data' DataFrame to the Datasets
df = pd.DataFrame()

data0 = pd.read_csv("tmdb.movies.csv")
data1 = pd.read_csv("tn.movie_budgets.csv")
data2 = pd.read_csv("bom.movie_gross.csv")

tn_movie_budgets = data1
bom_movies = data2
tmdb_movies = data0
# Combining the 'bom-movies' and the 'tmdb_movies' datasets on 'title column

combined_data = pd.merge(bom_movies, tmdb_movies, on=['title'], how='outer')
 
# Combining the resulting data above with 'tn_movie_budgets' dataset
df_combined = pd.concat([combined_data, tn_movie_budgets], join='outer')

df_combined['domestic_gross'] = df_combined['domestic_gross'].replace('[\$,]', '', regex=True).astype(float)

df_combined.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross    year  Unnamed: 0                genre_ids       id  \
# 0     652000000  2010.0         7.0          [16, 10751, 35]  10193.0
# 1     691300000  2010.0         NaN                      NaN      NaN
# 2     664300000  2010.0         NaN                      NaN      NaN
# 3     535700000  2010.0         4.0            [28, 878, 12]  27205.0
# 4     513900000  2010.0        38.0  [35, 12, 14, 16, 10751]  10192.0
#
#   original_language       original_title  popularity release_date  \
# ...

# %%
# Finding and handling missing values appropriately
df_combined.isna().sum()
# Out:
# title                 5782
# studio               29601
# domestic_gross       23846
# foreign_gross        31125
# year                 29596
# Unnamed: 0            6868
# genre_ids             6868
# id                    1086
# original_language     6868
# original_title        6868
# popularity            6868
# release_date          1086
# vote_average          6868
# vote_count            6868
# movie                27603
# production_budget    27603
# worldwide_gross      27603
# dtype: int64

# %%
df_combined =df_combined.drop(['Unnamed: 0', 'genre_ids', 'id', 'original_language'], axis=1)

# %%
# Displaying the descriptive statistics of the data
df_combined.describe()
# Out:
#        domestic_gross         year    popularity  vote_average    vote_count
# count    9.539000e+03  3789.000000  26517.000000  26517.000000  26517.000000
# mean     3.719435e+07  2014.077593      3.130912      5.991281    194.224837
# std      6.946465e+07     2.465238      4.355229      1.852946    960.961095
# min      0.000000e+00  2010.000000      0.600000      0.000000      1.000000
# 25%      3.117170e+05  2012.000000      0.600000      5.000000      2.000000
# 50%      9.534258e+06  2014.000000      1.374000      6.000000      5.000000
# 75%      4.452048e+07  2016.000000      3.694000      7.000000     28.000000
# max      9.367000e+08  2018.000000     80.773000     10.000000  22186.000000

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33385 entries, 0 to 5781
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              27603 non-null  object
#  1   studio             3784 non-null   object
#  2   domestic_gross     9539 non-null   float64
#  3   foreign_gross      2260 non-null   object
#  4   year               3789 non-null   float64
#  5   original_title     26517 non-null  object
#  6   popularity         26517 non-null  float64
#  7   release_date       32299 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  float64
#  10  movie              5782 non-null   object
#  11  production_budget  5782 non-null   object
#  12  worldwide_gross    5782 non-null   object
# dtypes: float64(5), object(8)
# memory usage: 3.6+ MB

# %% [markdown]
# # 3.2. Formatting Datatypes

# %%
# Converting the  release_date to datetime
df_combined['release_date'] = pd.to_datetime(df_combined['release_date'], errors='coerce')  # coerce converts invalid dates to NaT
# Converting 'domestic_gross' to float
df_combined['domestic_gross'] = df_combined['domestic_gross'].astype(float)

# Converting 'foreign_gross' to float
df_combined['foreign_gross'] = pd.to_numeric(df_combined['foreign_gross'], errors='coerce')  # coerce converts non-numeric values to NaN

# Converting 'year' to integer (assuming it's a year)
df_combined['year'] = df_combined['year'].astype('Int64')  # Use 'Int64' for nullable integer

# Converting 'release_date' to datetime


# Converting 'production_budget' and 'worldwide_gross' to float
df_combined['production_budget'] = pd.to_numeric(df_combined['production_budget'], errors='coerce')
df_combined['worldwide_gross'] = pd.to_numeric(df_combined['worldwide_gross'], errors='coerce')

df_combined.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year       original_title  popularity release_date  \
# 0    652000000.0  2010          Toy Story 3      24.445   2010-06-17
# 1    691300000.0  2010                  NaN         NaN          NaT
# 2    664300000.0  2010                  NaN         NaN          NaT
# 3    535700000.0  2010            Inception      27.920   2010-07-16
# 4    513900000.0  2010  Shrek Forever After      15.041   2010-05-16
#
#    vote_average  vote_count movie  production_budget  worldwide_gross
# ...

# %% [markdown]
# # 3.3. Data Wrangling

# %%
# Fill NAN values in 'release_date' column with mean
df_combined['release_date'] = df_combined['release_date'].fillna('2000-01-01')
df_combined['release_date'] = pd.to_datetime(df_combined['release_date'])
# Fill NAN values in 'vote_count' and 'vote_average' columns with mean
df_combined['vote_count'] = df_combined['vote_count'].fillna(df_combined['vote_count'].mean())
df_combined['vote_average'] = df_combined['vote_average'].fillna(df_combined['vote_average'].mean())
# Fill NAN values in 'domestic_gross', 'worldwide_gross' and 'foreign_gross' columns with 0
df_combined['domestic_gross'].fillna(0, inplace=True)
df_combined['worldwide_gross'].fillna(0, inplace=True)
df_combined['foreign_gross'].fillna(0, inplace=True)
# Drop NAN values in 'original_title' column
df_combined = df_combined.dropna(subset=['original_title'])
# Fill NAN values in 'studio' and 'movie' column with 'Uknown'
df_combined['movie'] = df_combined['movie'].fillna('Unknown')
df_combined['studio'] = df_combined['studio'].fillna('Unknown')
# Fill NAN values in 'production_budget' column with 0
df_combined['production_budget'] = df_combined['production_budget'].fillna(0)

# Sort the data by 'release_date' in ascending order
df_sorted = df_combined.sort_values(by='release_date', ascending=True)

# Reset the index
df_sorted = df_sorted.reset_index(drop=True)

df_sorted.head()
# Out:
#                                title   studio  domestic_gross  foreign_gross  \
# 0     All Quiet on the Western Front  Unknown             0.0            0.0
# 1                    The Vampire Bat  Unknown             0.0            0.0
# 2                         Le Bonheur  Unknown             0.0            0.0
# 3  How Walt Disney Cartoons Are Made  Unknown             0.0            0.0
# 4        The Best Years of Our Lives  Unknown             0.0            0.0
#
#    year                     original_title  popularity release_date  \
# 0  <NA>     All Quiet on the Western Front       9.583   1930-04-29
# 1  <NA>                    The Vampire Bat       2.292   1933-01-21
# 2  <NA>                         Le Bonheur       1.653   1936-02-27
# 3  <NA>  How Walt Disney Cartoons Are Made       0.600   1939-01-19
# 4  <NA>        The Best Years of Our Lives       9.647   1946-12-25
#
#    vote_average  vote_count    movie  production_budget  worldwide_gross
# ...

# %% [markdown]
# # 4.0.  Exploratory Data Analysis
# In this section we have to explore the data, perform calculations involving statistical methods (e.g,mean), finding the correlation between two variables and finally visualizing the data output.

# %%
# Showing the top ten movies according to domestic_gross
df_combined['domestic_gross'] = df_combined['domestic_gross'].replace('[\$,]', '', regex=True).astype(float)

# Sort the DataFrame by 'domestic_gross' in descending order
top_ten_movies = df_combined.sort_values(by='domestic_gross', ascending=False).head(10)

print(top_ten_movies[['title', 'domestic_gross']])
# Out:
#                              title  domestic_gross
# 1983  Star Wars: The Force Awakens     936700000.0
# 1982  Star Wars: The Force Awakens     936700000.0
# 3452                 Black Panther     700100000.0
# 3453                 Black Panther     700100000.0
# 3451        Avengers: Infinity War     678800000.0
# 1984                Jurassic World     652300000.0
# 3048      Star Wars: The Last Jedi     620200000.0
# 3049      Star Wars: The Last Jedi     620200000.0
# 3455                 Incredibles 2     608600000.0
# 2525  Rogue One: A Star Wars Story     532200000.0

# %%
# Visualizing the top_ten_movies
plt.figure(figsize=(12, 6))
plt.bar(top_ten_movies['title'], top_ten_movies['domestic_gross'], color='magenta')
plt.title('Top Ten Movies by Domestic Gross')
plt.xlabel('Movie Title')
plt.ylabel('Domestic Gross ($)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4.1. Statistical Methods
#
# Here we use the cleaned data to calculate measures of central tendency, measures of dispersion, correlation and visualize the output clearly.
#
# This helps in finding the relationship between various variables and probably guide in determining the be actions to take on the output.

# %%
# Measures of central tendency(Mean)
central_tendency = df_combined[['domestic_gross', 'foreign_gross', 'popularity', 'vote_average', 'vote_count']].mean()
print("Mean:", central_tendency)

# Measures of Dispersion(Standard Deviation)
std = df_combined[['domestic_gross', 'foreign_gross', 'popularity', 'vote_average', 'vote_count']].std()
print("Standard Deviation:", std)

# Calculating Interquartile Range (IQR) for Middle Fifty
IQR = df_combined[['domestic_gross', 'foreign_gross', 'popularity', 'vote_average', 'vote_count']].quantile([0.25, 0.75])
print("Interquartile Range (IQR):", IQR)


# Calculating Correlation Matrix
correlation_matrix = df_combined[['domestic_gross', 'foreign_gross', 'popularity', 'vote_average', 'vote_count']].corr()
print("Correlation Matrix:", correlation_matrix)
# Out:
# Mean: domestic_gross    3.670619e+06
# foreign_gross     5.437717e+06
# popularity        3.130912e+00
# vote_average      5.991281e+00
# vote_count        1.942248e+02
# dtype: float64
# Standard Deviation: domestic_gross    2.691957e+07
# foreign_gross     4.188393e+07
# popularity        4.355229e+00
# vote_average      1.852946e+00
# vote_count        9.609611e+02
# dtype: float64
# Interquartile Range (IQR):       domestic_gross  foreign_gross  popularity  vote_average  vote_count
# 0.25             0.0            0.0       0.600           5.0         2.0
# 0.75             0.0            0.0       3.694           7.0        28.0
# Correlation Matrix:                 domestic_gross  foreign_gross  popularity  vote_average  \
# domestic_gross        1.000000       0.815577    0.503110      0.051082
# foreign_gross         0.815577       1.000000    0.491557      0.048080
# popularity            0.503110       0.491557    1.000000      0.065273
# ...

# %% [markdown]
# # 5.0. Visualizations

# %%
# Plotting  Histograms 
df_combined[['domestic_gross', 'foreign_gross', 'popularity', 'vote_average', 'vote_count']].hist(bins=20, figsize=(15, 10))
plt.show()

# Boxplots with Clear Labels
plt.figure(figsize=(20, 10))
sns.boxplot(data=df_combined[['domestic_gross', 'foreign_gross', 'popularity', 'vote_average', 'vote_count']])
plt.title('Boxplots for Various Variables')
plt.ylabel('Values')
plt.xlabel('Variables')
plt.show()

# Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='popularity', y='vote_count', data=df_combined)
plt.title('Scatter Plot: Popularity vs Vote Count')
plt.show()

# Pairplot for a quick overview
sns.pairplot(df_combined[['domestic_gross', 'foreign_gross', 'popularity', 'vote_average', 'vote_count']])
plt.show()

# %%
# Finding the most popular movie using vote_count and popularity

# Sort the data by 'vote_count' and 'popularity' in descending order
df_sorted_by_vote_count = df_combined.sort_values(by='vote_count', ascending=False)
df_sorted_by_popularity = df_combined.sort_values(by='popularity', ascending=False)

# Retrieve the top ten most popular movies based on vote_count and popularity
top_ten_by_vote_count = df_sorted_by_vote_count.head(10)
top_ten_by_popularity = df_sorted_by_popularity.head(10)

# Visualization using bar plots
plt.figure(figsize=(15, 6))

# Bar plot for top ten most popular movies based on vote_count
plt.subplot(1, 2, 1)
sns.barplot(x='vote_count', y='original_title', data=top_ten_by_vote_count, palette='viridis')
plt.title('Top Ten Most Popular Movies (Vote Count)')
plt.show()

# %% [markdown]
# # 6.0. SUMMARY AND FINAL RECOMENDATION

# %% [markdown]
# The above extensive analysis shows the relationship between the various variables in the data and statistical alculations help get us deeper insight accompanied by vivid and clear visualizations.
#
# The domestic_gross and worldwide_gross clearly depicts the fact that the movie industry makes good money with the highest gross from 'Star Wars: The Force Awakens' premiered in 1983, this depicts the time a movie has been in the industry the better money it makes and is passive income, money that does not require management but grows like weeds on an annual timeframe, this also shows that movie fans love fiction movies better.
#
# The depition we get from the relationship between vote-count and popularity shows that the most voted movie was # 'Inception' premeired in 2010, after the rampant growth of social media platforms i.e, Facebook founded back in 2004.
# This contributed to popularity of movies back then.
#
# From the above conclusions therefore I would recommend that your company venture into the movie industry bearing in mind the intrinsic and intricate relationship between movie genres, movie popularity and social media platforms.
#
# The relationship shows a positive correlation between popularity and vote_count this shows that the more votes earned for a movie the more popular that particular movie is and is most probably from the Sci-fic genre, make the platform generally dominant of these.
